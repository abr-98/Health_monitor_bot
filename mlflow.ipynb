# %%
import mlflow

# %%
mlflow.set_experiment("test")
# Out:
# 2026/03/25 11:58:24 INFO mlflow.tracking.fluent: Experiment with name 'test' does not exist. Creating a new experiment.
# <Experiment: artifact_location='/Users/abhijit/Desktop/Stock_Project/mlFlow_and_mcp/mlruns/1', creation_time=1774420104291, experiment_id='1', last_update_time=1774420104291, lifecycle_stage='active', name='test', tags={}, workspace='default'>
